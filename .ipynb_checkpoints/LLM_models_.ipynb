# %%
import pandas as pd

# %%
# !pip install langchain
# !pip install -U langchain-community

# %%
file_path=pd.read_csv(r"C:\Users\saiprithi\Documents\naresh it\datasience ai\DEEPLEARNIG\winequality_red.csv")
file_path
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
import os
print("Current working directory:", os.getcwd())
# Out:
# Current working directory: C:\Users\saiprithi\Documents\naresh it\datasience ai\DEEPLEARNIG

# %%
from langchain_community.document_loaders.csv_loader import CSVLoader

loader = CSVLoader(file_path='winequality_red.csv'
)
data = loader.load()

# %%
# !pip install -U langchain langchain-community

# %%
from langchain_community.document_loaders import PyPDFLoader

file_path =r "C:\Users\saiprithi\Documents\naresh it\datasience ai\DEEPLEARNIG.pdf"
loader = PyPDFLoader(file_path)
# Out:
#   Cell In[31], line 3
#     file_path =r "C:\Users\saiprithi\Documents\naresh it\datasience ai\DEEPLEARNIG.pdf"
#                  ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
# !pip install  pypdf
