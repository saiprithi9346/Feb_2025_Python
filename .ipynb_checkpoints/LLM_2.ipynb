# %%
pip install -U langchain-google-genai
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_google_genai import GoogleGenerativeAIEmbeddings

embeddings = GoogleGenerativeAIEmbeddings(model="models/gemini-embedding-exp-03-07",
                                         google_api_key="AIzaSyCBIH3cjjyrj5dTKlTtIssq6CiJ3E_XRck")
vector = embeddings.embed_query("What are embeddings?")
print(vector[:5])
# Out:
# [-0.004947314038872719, 0.01406385563313961, -0.028872955590486526, -0.0790993943810463, 0.0002928560716100037]

# %%
documents=[
    "saiprithi is a very strong women.",
    "raviteja now a days ver week person.",
    "we both get married in few years.",
]
vectors_list=[]
for i in documents:
    vc=embeddings.embed_query(i)
    vectors_list.append(vc)
# Query vector
query="who is the most strong person?"
query_embedding=embeddings.embed_query(query)

# %%
vectors_list
# Out:
# [[0.010381744243204594,
#   0.0024372823536396027,
#   -0.004200794268399477,
#   -0.06172363460063934,
#   -0.026898516342043877,
#   0.009480413980782032,
#   0.025401553139090538,
#   0.012407691217958927,
#   0.02101404033601284,
#   0.012812836095690727,
#   -0.00482881348580122,
#   -0.004520766902714968,
#   -0.01512580830603838,
#   0.04718553274869919,
#   0.11166895925998688,
#   0.012323274277150631,
#   -0.005124129820615053,
#   0.028938258066773415,
#   0.02151026949286461,
#   -0.00676333112642169,
#   -0.01693650707602501,
#   -0.03047882206737995,
#   0.01501677930355072,
#   -0.008224018849432468,
#   -0.007649701088666916,
#   -0.014665802009403706,
#   0.02903428114950657,
#   0.006964292377233505,
#   0.0030897303950041533,
#   0.014986253343522549,
#   -0.006993214599788189,
#   -0.02746446058154106,
#   -0.015742437914013863,
#   0.009495456703007221,
#   0.024083847180008888,
#   0.006070045754313469,
#   0.026506636291742325,
#   0.028629692271351814,
# ...

# %%
len(vectors_list[0]),len(vectors_list[1]),len(vectors_list[2]),len(query_embedding)
# Out:
# (3072, 3072, 3072, 3072)

# %%
import numpy as np
v1=np.array(vectors_list[0])
v2=np.array(vectors_list[1])
v3=np.array(vectors_list[2])
qn_v=np.array(query_embedding)
np.dot(v1,qn_v),np.dot(v2,qn_v),np.dot(v3,qn_v)
# Out:
# (0.6644330438615661, 0.5510988736877966, 0.5352293024072848)

# %%
from langchain_google_genai import GoogleGenerativeAIEmbeddings

embeddings = GoogleGenerativeAIEmbeddings(model="models/gemini-embedding-exp-03-07",
                                         google_api_key="AIzaSyCBIH3cjjyrj5dTKlTtIssq6CiJ3E_XRck")
vector = embeddings.embed_query("What are embeddings?")
print(vector[:5])


documents=[
    "saiprithi is a very strong women.",
    "raviteja now a days ver week person.",
    "we both get married in few years.",
    "we dont know we will married or not",
]
vectors_list=[]
for i in documents:
    vc=embeddings.embed_query(i)
    vectors_list.append(vc)
# Query vector
query="what is the main matter about both persons"
query_embedding=embeddings.embed_query(query)

import numpy as np
v1=np.array(vectors_list[0])
v2=np.array(vectors_list[1])
v3=np.array(vectors_list[2])
v4=np.array(vectors_list[3])
qn_v=np.array(query_embedding)
np.dot(v1,qn_v),np.dot(v2,qn_v),np.dot(v3,qn_v),np.dot(v4,qn_v)
# Out:
# [-0.004947314038872719, 0.01406385563313961, -0.028872955590486526, -0.0790993943810463, 0.0002928560716100037]
# (0.5711898799131438, 0.549299662888481, 0.6626234937331161, 0.614312764777275)
